# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\sagiri\lego_sets.csv")
df
# Out:
#                set_id                     name  year                theme  \
# 0                 1-8          Small house set  1970            Minitalia
# 1                 2-8         Medium house set  1970            Minitalia
# 2                 3-6         Medium house set  1970            Minitalia
# 3                 4-4          Large house set  1970            Minitalia
# 4                 4-6  Mini House and Vehicles  1970            Samsonite
# ...               ...                      ...   ...                  ...
# 18452       SHUTTLE-1            Space Shuttle  2022          Promotional
# 18453       SLSDUCK-1                 SLS Duck  2022          Promotional
# 18454    SUMMERWAVE-1              Summer Wave  2022          Promotional
# 18455  TRUSPIDERMAN-1               Spider-Man  2022  Marvel Super Heroes
# 18456          YOTT-1                    Tiger  2022        Miscellaneous
#
#                 subtheme     themeGroup category  pieces  minifigs  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18457 entries, 0 to 18456
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   set_id          18457 non-null  object
#  1   name            18457 non-null  object
#  2   year            18457 non-null  int64
#  3   theme           18457 non-null  object
#  4   subtheme        14901 non-null  object
#  5   themeGroup      18455 non-null  object
#  6   category        18457 non-null  object
#  7   pieces          14533 non-null  float64
#  8   minifigs        8399 non-null   float64
#  9   agerange_min    6787 non-null   float64
#  10  US_retailPrice  6982 non-null   float64
#  11  bricksetURL     18457 non-null  object
#  12  thumbnailURL    17451 non-null  object
#  13  imageURL        17451 non-null  object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.0+ MB

# %% [markdown]
# ## 1. How many LEGO sets have been released since 1970? Is there a noticable trend?

# %%
lego_1970 = df[df["year"] == 1970]
lego_1970.head(10)
# Out:
#   set_id                      name  year      theme             subtheme  \
# 0    1-8           Small house set  1970  Minitalia                  NaN
# 1    2-8          Medium house set  1970  Minitalia                  NaN
# 2    3-6          Medium house set  1970  Minitalia                  NaN
# 3    4-4           Large house set  1970  Minitalia                  NaN
# 4    4-6   Mini House and Vehicles  1970  Samsonite          Model Maker
# 5  078-1  Roadway Base Plate 50X50  1970  Samsonite         Supplemental
# 6  104-1    4.5V Replacement Motor  1970     Trains  Supplemental / 4.5V
# 7  126-1   Steam Locomotive (Push)  1970     Trains                 4.5v
# 8  157-3      4 Car Auto Transport  1970  Samsonite          Model Maker
# 9  242-4            Big Model Book  1970      Books                 LEGO
#
#       themeGroup category  pieces  minifigs  agerange_min  US_retailPrice  \
# 0        Vintage   Normal    67.0       NaN           NaN             NaN
# ...

# %%
rilis_1970 = lego_1970.shape

# %%
rilis_1970
# Out:
# (41, 14)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(2, 5))
plt.bar(['Rows'], rilis_1970)
plt.title('Count Lego rilis in 1970')
plt.xlabel('Dimensions')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### There were 41 Legos released in 1970

# %%
trend = lego_1970.groupby("themeGroup")

# %%
trend_count = trend["themeGroup"].count()

# %%
trend_count
# Out:
# themeGroup
# Basic             4
# Miscellaneous     1
# Modern day        7
# Pre-school        2
# Vintage          27
# Name: themeGroup, dtype: int64

# %%
plt.figure(figsize=(8, 6))
trend_count.plot(kind = 'bar')
plt.title('Trend Theme Group')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### From the data above, it can be seen that the trend that was occurring in 1970 was the vintage theme group

# %% [markdown]
# ## 2. Is there a relationship between the price of a set and its number of pieces?

# %%
relationship = df[["pieces","US_retailPrice"]]
relationship.head()
# Out:
#    pieces  US_retailPrice
# 0    67.0             NaN
# 1   109.0             NaN
# 2   158.0             NaN
# 3   233.0             NaN
# 4     NaN             NaN

# %%
relationship2 = relationship[relationship["US_retailPrice"].notna()]
relationship2
# Out:
#        pieces  US_retailPrice
# 1986      8.0           12.99
# 1987      8.0           12.99
# 1988      6.0           27.99
# 1993      3.0           41.99
# 2111      1.0           14.99
# ...       ...             ...
# 18376     NaN           42.00
# 18377     NaN           59.99
# 18378     NaN           59.99
# 18379     NaN           59.99
# 18447     NaN           17.95
#
# [6982 rows x 2 columns]

# %%
relationship3 = relationship2[relationship2["pieces"].notna()]
relationship3
# Out:
#        pieces  US_retailPrice
# 1986      8.0           12.99
# 1987      8.0           12.99
# 1988      6.0           27.99
# 1993      3.0           41.99
# 2111      1.0           14.99
# ...       ...             ...
# 18025   880.0           79.99
# 18026  1406.0          129.99
# 18027  2433.0          189.99
# 18028  1066.0           79.99
# 18029  1519.0          119.99
#
# [5322 rows x 2 columns]

# %%
korelasi = relationship3['US_retailPrice'].corr(df['pieces'], method='pearson')
korelasi
# Out:
# 0.8674332912536639

# %%
korelasi2 = np.corrcoef(relationship3['US_retailPrice'], relationship3['pieces'])

# %%
pearson_korelasi = korelasi2[0, 1]
pearson_korelasi
# Out:
# 0.8674332912536639

# %%
import seaborn as sns

# %%
plt.figure()
sns.scatterplot(x=relationship3['US_retailPrice'], y=relationship3['pieces'])
plt.title('Correlation between US Retail Price and Number of Pieces')
plt.xlabel('US Retail Price')
plt.ylabel('Number of Pieces')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sagiri\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\sagiri\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Setelah menghitung korelasi Pearson
if pearson_korelasi > 0.5:
    print("There is a strong positive relationship between the price of a set and the number of pieces.")
elif 0.3 < pearson_korelasi <= 0.5:
    print("There is a moderate positive relationship between the price of a set and the number of pieces..")
elif -0.3 <= pearson_korelasi <= 0.3:
    print("There is no linear relationship between the price of a set and the number of pieces.")
elif -0.5 <= pearson_korelasi < -0.3:
    print("There is a moderate negative relationship between the price of a set and the number of pieces.")
else:
    print("There is a strong negative relationship between the price of a set and the number of pieces.")
# Out:
# There is a strong positive relationship between the price of a set and the number of pieces.

# %% [markdown]
# ## 3. Which has been the most popular theme in each decade?

# %%
dekade = df[["year","theme"]]
dekade
# Out:
#        year                theme
# 0      1970            Minitalia
# 1      1970            Minitalia
# 2      1970            Minitalia
# 3      1970            Minitalia
# 4      1970            Samsonite
# ...     ...                  ...
# 18452  2022          Promotional
# 18453  2022          Promotional
# 18454  2022          Promotional
# 18455  2022  Marvel Super Heroes
# 18456  2022        Miscellaneous
#
# [18457 rows x 2 columns]

# %%
def get_dekade(year):
    return str(year // 10 * 10) + "s"

# %%
dekade['decade'] = dekade['year'].apply(get_dekade)
# Out:
# C:\Users\sagiri\AppData\Local\Temp\ipykernel_4648\4271007236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dekade['decade'] = dekade['year'].apply(get_dekade)

# %%
dekade
# Out:
#        year                theme decade
# 0      1970            Minitalia  1970s
# 1      1970            Minitalia  1970s
# 2      1970            Minitalia  1970s
# 3      1970            Minitalia  1970s
# 4      1970            Samsonite  1970s
# ...     ...                  ...    ...
# 18452  2022          Promotional  2020s
# 18453  2022          Promotional  2020s
# 18454  2022          Promotional  2020s
# 18455  2022  Marvel Super Heroes  2020s
# 18456  2022        Miscellaneous  2020s
#
# [18457 rows x 3 columns]

# %%
themes = dekade.groupby(['decade', 'theme']).size().reset_index(name='count')

# %%
popular_theme = themes.loc[themes.groupby('decade')['count'].idxmax()]

# %%
print(popular_theme)
# Out:
#     decade     theme  count
# 10   1970s  LEGOLAND    159
# 41   1980s      Town    190
# 73   1990s      Town    346
# 110  2000s      Gear    892
# 174  2010s      Gear   1306
# 249  2020s      Gear    585

# %%
#data
themess = popular_theme['theme']
counts = popular_theme['count']

# %%
plt.figure(figsize=(8, 6))
plt.bar(themess, counts, color= 'skyblue')
plt.title('Popular Theme in each decade')
plt.xlabel('themess')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 4. Are LEGO minifigures most closely tied to licensed sets?

# %%
mnf = df[["theme","minifigs"]]
mnf
# Out:
#                      theme  minifigs
# 0                Minitalia       NaN
# 1                Minitalia       NaN
# 2                Minitalia       NaN
# 3                Minitalia       NaN
# 4                Samsonite       NaN
# ...                    ...       ...
# 18452          Promotional       NaN
# 18453          Promotional       NaN
# 18454          Promotional       NaN
# 18455  Marvel Super Heroes       NaN
# 18456        Miscellaneous       NaN
#
# [18457 rows x 2 columns]

# %%
mnf2 = mnf[mnf["minifigs"].notna()]

# %%
mnf2
# Out:
#              theme  minifigs
# 289         Trains       5.0
# 297       LEGOLAND       2.0
# 298       LEGOLAND       7.0
# 299       LEGOLAND       7.0
# 300       LEGOLAND       8.0
# ...            ...       ...
# 18145         City       1.0
# 18146    Education       4.0
# 18149      Friends       7.0
# 18394  Promotional       1.0
# 18436        Books       1.0
#
# [8399 rows x 2 columns]

# %%
licensed_theme = mnf2[mnf2['theme'].str.contains('LEGOLAND|Education|Books|...')]

# %%
correlation = licensed_theme['minifigs'].corr(licensed_theme['theme'].astype('category').cat.codes)

# %%
print(correlation)
# Out:
# 0.02827326666208772

# %% [markdown]
# ### minifigs have nothing to do with licensed devices
